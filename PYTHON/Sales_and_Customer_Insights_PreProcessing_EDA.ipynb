# %% [markdown]
# # STEP :1 Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\VINOTH\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
np
# Out:
# <module 'numpy' from 'C:\\Users\\VINOTH\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\numpy\\__init__.py'>

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\VINOTH\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sns
# Out:
# <module 'seaborn' from 'C:\\Users\\VINOTH\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\seaborn\\__init__.py'>

# %% [markdown]
# # STEP 2: Load CSV File

# %%
df=pd.read_csv("Sample_Dataset_Validated.csv")

#Drop all columns with unnamed 
df=df.loc[:,~df.columns.str.contains('^Unnamed:')]

# %%
df
# Out:
#             Date Customer Acquisition Type           State    Product  Price  \
# 0     03-01-2017                        Ad         Alabama  Product 1    499
# 1     06-01-2017                        Ad     Mississippi  Product 1    499
# 2     06-01-2017                        Ad         Florida  Product 1    499
# 3     10-01-2017                        Ad  South Carolina  Product 1    499
# 4     13-01-2017                        Ad         Florida  Product 1    499
# ...          ...                       ...             ...        ...    ...
# 5773  13-12-2019                 Returning     Mississippi  Product 5    399
# 5774  19-12-2019                 Returning  South Carolina  Product 5    399
# 5775  21-12-2019                 Returning  South Carolina  Product 5    399
# 5776  30-12-2019                 Returning  South Carolina  Product 5    399
# 5777  30-12-2019                 Returning         Florida  Product 5    399
#
# ...

# %%
df.head()
# Out:
#          Date Customer Acquisition Type           State    Product  Price  \
# 0  03-01-2017                        Ad         Alabama  Product 1    499
# 1  06-01-2017                        Ad     Mississippi  Product 1    499
# 2  06-01-2017                        Ad         Florida  Product 1    499
# 3  10-01-2017                        Ad  South Carolina  Product 1    499
# 4  13-01-2017                        Ad         Florida  Product 1    499
#
#    Units  Revenue Delivery Performance Return Customer Satisfaction
# 0     10     4990              on-time     no                (3) ok
# 1     10     4990              on-time     no              (4) high
# 2      5     2495              on-time     no                (3) ok
# 3      9     4491              delayed     no          (1) very low
# 4      2      998              delayed     no              (4) high

# %%
df.tail()
# Out:
#             Date Customer Acquisition Type           State    Product  Price  \
# 5773  13-12-2019                 Returning     Mississippi  Product 5    399
# 5774  19-12-2019                 Returning  South Carolina  Product 5    399
# 5775  21-12-2019                 Returning  South Carolina  Product 5    399
# 5776  30-12-2019                 Returning  South Carolina  Product 5    399
# 5777  30-12-2019                 Returning         Florida  Product 5    399
#
#       Units  Revenue Delivery Performance Return Customer Satisfaction
# 5773      3     1197              on-time     no                (3) ok
# 5774      3     1197              on-time     no              (4) high
# 5775      9     3591              on-time     no                (3) ok
# 5776      1      399              on-time     no                (3) ok
# 5777      9     3591              on-time     no          (1) very low

# %%
df.describe()
# Out:
#              Price        Units      Revenue
# count  5778.000000  5778.000000  5778.000000
# mean    300.124957     5.491346  1658.925407
# std     141.165729     2.861407  1247.976568
# min      99.000000     1.000000    99.000000
# 25%     199.000000     3.000000   598.000000
# 50%     299.000000     5.000000  1393.000000
# 75%     399.000000     8.000000  2394.000000
# max     499.000000    10.000000  4990.000000

# %%
df.shape
# Out:
# (5778, 10)

# %%
df.dtypes
# Out:
# Date                         object
# Customer Acquisition Type    object
# State                        object
# Product                      object
# Price                         int64
# Units                         int64
# Revenue                       int64
# Delivery Performance         object
# Return                       object
# Customer Satisfaction        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5778 entries, 0 to 5777
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       5778 non-null   object
#  1   Customer Acquisition Type  5778 non-null   object
#  2   State                      5778 non-null   object
#  3   Product                    5778 non-null   object
#  4   Price                      5778 non-null   int64
#  5   Units                      5778 non-null   int64
#  6   Revenue                    5778 non-null   int64
#  7   Delivery Performance       5778 non-null   object
#  8   Return                     5778 non-null   object
#  9   Customer Satisfaction      5778 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 451.5+ KB

# %% [markdown]
# # STEP 3: PREPROCESSING
#                   DATA CLEANING

# %%
df.dropna()
# Out:
#             Date Customer Acquisition Type           State    Product  Price  \
# 0     03-01-2017                        Ad         Alabama  Product 1    499
# 1     06-01-2017                        Ad     Mississippi  Product 1    499
# 2     06-01-2017                        Ad         Florida  Product 1    499
# 3     10-01-2017                        Ad  South Carolina  Product 1    499
# 4     13-01-2017                        Ad         Florida  Product 1    499
# ...          ...                       ...             ...        ...    ...
# 5773  13-12-2019                 Returning     Mississippi  Product 5    399
# 5774  19-12-2019                 Returning  South Carolina  Product 5    399
# 5775  21-12-2019                 Returning  South Carolina  Product 5    399
# 5776  30-12-2019                 Returning  South Carolina  Product 5    399
# 5777  30-12-2019                 Returning         Florida  Product 5    399
#
# ...

# %%
pd.set_option('display.max_columns', None)
df.describe(include="all").round(2)
# Out:
#               Date Customer Acquisition Type    State    Product    Price  \
# count         5778                      5778     5778       5778  5778.00
# unique        1095                         3        7          5      NaN
# top     02-01-2018                        Ad  Florida  Product 5      NaN
# freq            33                      1981      859       1171      NaN
# mean           NaN                       NaN      NaN        NaN   300.12
# std            NaN                       NaN      NaN        NaN   141.17
# min            NaN                       NaN      NaN        NaN    99.00
# 25%            NaN                       NaN      NaN        NaN   199.00
# 50%            NaN                       NaN      NaN        NaN   299.00
# 75%            NaN                       NaN      NaN        NaN   399.00
# max            NaN                       NaN      NaN        NaN   499.00
#
#           Units  Revenue Delivery Performance Return Customer Satisfaction
# ...

# %%
df['Product'].nunique()
# Out:
# 5

# %%
df['State'].value_counts()
# Out:
# State
# Florida           859
# South Carolina    854
# Georgia           841
# Tennessee         808
# Mississippi       807
# North Carolina    806
# Alabama           803
# Name: count, dtype: int64

# %%
df
# Out:
#             Date Customer Acquisition Type           State    Product  Price  \
# 0     03-01-2017                        Ad         Alabama  Product 1    499
# 1     06-01-2017                        Ad     Mississippi  Product 1    499
# 2     06-01-2017                        Ad         Florida  Product 1    499
# 3     10-01-2017                        Ad  South Carolina  Product 1    499
# 4     13-01-2017                        Ad         Florida  Product 1    499
# ...          ...                       ...             ...        ...    ...
# 5773  13-12-2019                 Returning     Mississippi  Product 5    399
# 5774  19-12-2019                 Returning  South Carolina  Product 5    399
# 5775  21-12-2019                 Returning  South Carolina  Product 5    399
# 5776  30-12-2019                 Returning  South Carolina  Product 5    399
# 5777  30-12-2019                 Returning         Florida  Product 5    399
#
# ...

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#             Date Customer Acquisition Type           State    Product  Price  \
# 0     03-01-2017                        Ad         Alabama  Product 1    499
# 1     06-01-2017                        Ad     Mississippi  Product 1    499
# 2     06-01-2017                        Ad         Florida  Product 1    499
# 3     10-01-2017                        Ad  South Carolina  Product 1    499
# 4     13-01-2017                        Ad         Florida  Product 1    499
# ...          ...                       ...             ...        ...    ...
# 5773  13-12-2019                 Returning     Mississippi  Product 5    399
# 5774  19-12-2019                 Returning  South Carolina  Product 5    399
# 5775  21-12-2019                 Returning  South Carolina  Product 5    399
# 5776  30-12-2019                 Returning  South Carolina  Product 5    399
# 5777  30-12-2019                 Returning         Florida  Product 5    399
#
# ...

# %% [markdown]
# ### A. Find missing values in all columns

# %%
df.isnull()
# Out:
#        Date  Customer Acquisition Type  State  Product  Price  Units  Revenue  \
# 0     False                      False  False    False  False  False    False
# 1     False                      False  False    False  False  False    False
# 2     False                      False  False    False  False  False    False
# 3     False                      False  False    False  False  False    False
# 4     False                      False  False    False  False  False    False
# ...     ...                        ...    ...      ...    ...    ...      ...
# 5773  False                      False  False    False  False  False    False
# 5774  False                      False  False    False  False  False    False
# 5775  False                      False  False    False  False  False    False
# 5776  False                      False  False    False  False  False    False
# 5777  False                      False  False    False  False  False    False
#
# ...

# %%
df.isnull().sum()
# Out:
# Date                         0
# Customer Acquisition Type    0
# State                        0
# Product                      0
# Price                        0
# Units                        0
# Revenue                      0
# Delivery Performance         0
# Return                       0
# Customer Satisfaction        0
# dtype: int64

# %% [markdown]
# ### B. Fill all missing values with 0

# %%
df= df.fillna(0)

# %%
df.isnull()
# Out:
#        Date  Customer Acquisition Type  State  Product  Price  Units  Revenue  \
# 0     False                      False  False    False  False  False    False
# 1     False                      False  False    False  False  False    False
# 2     False                      False  False    False  False  False    False
# 3     False                      False  False    False  False  False    False
# 4     False                      False  False    False  False  False    False
# ...     ...                        ...    ...      ...    ...    ...      ...
# 5773  False                      False  False    False  False  False    False
# 5774  False                      False  False    False  False  False    False
# 5775  False                      False  False    False  False  False    False
# 5776  False                      False  False    False  False  False    False
# 5777  False                      False  False    False  False  False    False
#
# ...

# %%
df.isnull().sum()
# Out:
# Date                         0
# Customer Acquisition Type    0
# State                        0
# Product                      0
# Price                        0
# Units                        0
# Revenue                      0
# Delivery Performance         0
# Return                       0
# Customer Satisfaction        0
# dtype: int64

# %% [markdown]
# # STEP 4: Data Aggregation:

# %% [markdown]
# ### A). Find max value in all columns using groupby function on 'STATE' column

# %%
df.groupby('State').max().reset_index()
# Out:
#             State        Date Customer Acquisition Type    Product  Price  \
# 0         Alabama  31-12-2019                 Returning  Product 5    499
# 1         Florida  31-12-2017                 Returning  Product 5    499
# 2         Georgia  31-12-2019                 Returning  Product 5    499
# 3     Mississippi  31-12-2018                 Returning  Product 5    499
# 4  North Carolina  31-12-2018                 Returning  Product 5    499
# 5  South Carolina  31-12-2019                 Returning  Product 5    499
# 6       Tennessee  31-12-2019                 Returning  Product 5    499
#
#    Units  Revenue Delivery Performance Return Customer Satisfaction
# 0     10     4990              on-time    yes         (5) very high
# 1     10     4990              on-time    yes         (5) very high
# 2     10     4990              on-time    yes         (5) very high
# 3     10     4990              on-time    yes         (5) very high
# ...

# %% [markdown]
# # STEP 5: Exploratory Data Analysis - EDA

# %%
# ------------------------------
#  KPIs (Key Metrics)
# ------------------------------
#print("Total Units Returned:", df['Return'].sum())
# KPI 1: Total Units Returned
units_returned = df.loc[df["Return"].str.lower() == "yes", "Units"].sum()
print("Total Units Returned:", units_returned)
# Sum of Units by Return (Yes/No)
units_by_return = df.groupby("Return")["Units"].sum().reset_index()

print("📊 Sum of Units by Return")
print(units_by_return)
print("📊 Sum of Revenue by State")
revenue_by_state = df.groupby("State")["Revenue"].sum().reset_index()
print(revenue_by_state)
print("Total Revenue:", df['Revenue'].sum())

print("Total Price:", df['Price'].sum())
print("Total Sales:", df['Revenue'].sum())   # Sales = Revenue here
# Out:
# Total Units Returned: 3216
# 📊 Sum of Units by Return
#   Return  Units
# 0     no  28513
# 1    yes   3216
# 📊 Sum of Revenue by State
#             State  Revenue
# 0         Alabama  1353090
# 1         Florida  1412456
# 2         Georgia  1381150
# 3     Mississippi  1376333
# 4  North Carolina  1314385
# 5  South Carolina  1439553
# 6       Tennessee  1308304
# Total Revenue: 9585271
# Total Price: 1734122
# Total Sales: 9585271

# %%
# ------------------------------
#  Revenue by Product
# ------------------------------
plt.figure(figsize=(6,4))
sns.barplot(x="Product", y="Revenue", data=df, estimator=sum)
plt.title("Sum of Revenue by Product")
plt.show()

# %%
# ------------------------------
#  Revenue by Acquisition Type
# ------------------------------
plt.figure(figsize=(6,6))
df.groupby("Customer Acquisition Type")["Revenue"].sum().plot.pie(
    autopct="%1.1f%%", startangle=90, explode=[0.05]*df["Customer Acquisition Type"].nunique()
)
plt.title("Revenue by Customer Acquisition Type")
plt.ylabel("")
plt.show()

# %%
# ------------------------------
#  Revenue by State
# ------------------------------
plt.figure(figsize=(8,4))
sns.barplot(x="State", y="Revenue", data=df, estimator=sum)
plt.title("Sum of Revenue by State")
plt.xticks(rotation=45)
plt.show()

# %%
# ------------------------------
#  Revenue Trend by Year
# ------------------------------
plt.figure(figsize=(6,4))
sns.lineplot(x="Date", y="Revenue", data=df, estimator=sum, marker="o")
plt.title("Revenue by Year")
plt.show()

# %%
# ------------------------------

#  Return Count by Product
# ------------------------------
plt.figure(figsize=(6,4))
sns.countplot(x="Product", hue="Return", data=df)
plt.title("Return Count by Product")
plt.show()

# %%
# ------------------------------
# Customer Satisfaction
# ------------------------------
plt.figure(figsize=(6,4))
sns.countplot(x="Customer Satisfaction", data=df, order=df["Customer Satisfaction"].value_counts().index)
plt.title("Customer Satisfaction Distribution")
plt.show()
